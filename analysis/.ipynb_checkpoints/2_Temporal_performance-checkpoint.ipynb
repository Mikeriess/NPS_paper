# %% [markdown]
# ## <b>RQ2.1:</b> How does the number of agents influence the baseline (FCFS) queue waiting time in the simulation period?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc={'figure.figsize':(14,9)})
sns.set_style("whitegrid")

# %%
# load the experiments
experiments = pd.read_csv("../results/experiments.csv")
experiments.head(10)
# Out:
#   F_priority_scheme  F_number_of_agents F_SLA  burn_in  days   startdate  \
# 0              FCFS                   3  NONE      180   730  2018-01-01
# 1              SRTF                   3  NONE      180   730  2018-01-01
# 2              LRTF                   3  NONE      180   730  2018-01-01
# 3               NPS                   3  NONE      180   730  2018-01-01
# 4           NPS-SLA                   3  NONE      180   730  2018-01-01
# 5              FCFS                   6  NONE      180   730  2018-01-01
# 6              SRTF                   6  NONE      180   730  2018-01-01
# 7              LRTF                   6  NONE      180   730  2018-01-01
# 8               NPS                   6  NONE      180   730  2018-01-01
# 9           NPS-SLA                   6  NONE      180   730  2018-01-01
#
#    service_level  repetition  closed_avg_simulated_NPS  \
# 0            2.0           0                  8.661534
# 1            2.0           0                  8.921220
# 2            2.0           0                  8.927142
# 3            2.0           0                  9.356360
# 4            2.0           0                  8.628731
# 5            2.0           0                  8.852165
# 6            2.0           0                  9.067581
# 7            2.0           0                  9.060441
# 8            2.0           0                  8.944875
# 9            2.0           0                  8.903542
#
#    closed_avg_simulated_throughput_time  ...  all_avg_duration_delayed  \
# 0                            224.613380  ...                  0.411667
# 1                             19.023397  ...                  0.423214
# 2                             13.870325  ...                  0.427771
# 3                             13.113973  ...                  0.414703
# 4                            245.618041  ...                  0.430152
# 5                             61.947174  ...                  0.415728
# 6                             13.149705  ...                  0.421182
# 7                             12.971740  ...                  0.427110
# 8                             10.779307  ...                  0.419127
# 9                             38.020606  ...                  0.426384
#
#    cases_arrived  cases_closed  case_queued  cases_assigned_at_end  \
# 0           1267           388          876                    391
# 1           1273           436          834                    439
# 2           1366           433          930                    436
# 3           1188           443          742                    444
# 4           1302           336          963                    338
# 5           1305           892          407                    897
# 6           1259           868          385                    872
# 7           1292           884          402                    889
# 8           1299           880          413                    884
# 9           1188           878          304                    883
#
#    min_tracelen  max_tracelen  Simulation_duration_min  RUN  Done
# 0             1            13                       -1    0     0
# 1             1            13                       -1    1     0
# 2             1            12                       -1    2     0
# 3             1            13                       -1    3     0
# 4             1            14                       -1    4     0
# 5             1            11                       -1    5     0
# 6             1            13                       -1    6     0
# 7             1            15                       -1    7     0
# 8             1            13                       -1    8     0
# 9             1            11                       -1    9     0
#
# [10 rows x 33 columns]

# %%
len(experiments)
# Out:
# 2000

# %%
i = 3

# %%
experiments.loc[i].to_dict()
# Out:
# {'F_priority_scheme': 'NPS',
#  'F_number_of_agents': 3,
#  'F_SLA': 'NONE',
#  'burn_in': 180,
#  'days': 730,
#  'startdate': '2018-01-01',
#  'service_level': 2.0,
#  'repetition': 0,
#  'closed_avg_simulated_NPS': 9.35636003651745,
#  'closed_avg_simulated_throughput_time': 13.113973092418648,
#  'closed_avg_predicted_NPS': 10.10434806253795,
#  'closed_avg_predicted_throughput_time': 2.460368519589051,
#  'closed_avg_predicted_NPS_priority': 2.604348062537946,
#  'closed_avg_initial_delay': 9.357436240268171,
#  'closed_avg_activity_start_delay': 0.4151361503675139,
#  'closed_avg_duration_delayed': 0.4151361503675139,
#  'all_avg_simulated_NPS': 9.356823529723409,
#  'all_avg_simulated_throughput_time': 13.11708768707284,
#  'all_avg_predicted_NPS': 10.10436426460514,
#  'all_avg_predicted_throughput_time': 2.4597615123037118,
#  'all_avg_predicted_NPS_priority': 2.604364264605134,
#  'all_avg_initial_delay': 9.343808905937689,
#  'all_avg_activity_start_delay': 0.4147030504733744,
#  'all_avg_duration_delayed': 0.4147030504733744,
#  'cases_arrived': 1188,
#  'cases_closed': 443,
#  'case_queued': 742,
#  'cases_assigned_at_end': 444,
#  'min_tracelen': 1,
#  'max_tracelen': 13,
#  'Simulation_duration_min': -1,
#  'RUN': 3,
#  'Done': 0}

# %%
# load a single run
df = pd.read_csv("../results/"+str(i)+"/"+str(i)+"_timeseries.csv")
df.head()
# Out:
#    day  n_cases_caseDB  n_cases_future_arrival  n_cases_arrived  \
# 0    0            1424                    1423                1
# 1    1            1424                    1421                3
# 2    2            1424                    1420                4
# 3    3            1424                    1417                7
# 4    4            1424                    1417                7
#
#    n_cases_waiting_in_queue  n_cases_in_process  n_cases_assigned_total  \
# 0                         0                   0                       0
# 1                         0                   0                       1
# 2                         0                   0                       3
# 3                         0                   0                       4
# 4                         1                   0                       6
#
#    n_cases_closed_total  n_agents  n_busy_agents  \
# 0                     0         3              0
# 1                     0         3              1
# 2                     0         3              3
# 3                     1         3              3
# 4                     3         3              3
#
#    avg_current_queue_waitingtime  min_current_queue_waitingtime  \
# 0                       0.000000                       0.000000
# 1                       0.000000                       0.000000
# 2                       0.000000                       0.000000
# 3                       0.000000                       0.000000
# 4                       0.120096                       0.120096
#
#    max_current_queue_waitingtime  median_current_queue_waitingtime  \
# 0                       0.000000                          0.000000
# 1                       0.000000                          0.000000
# 2                       0.000000                          0.000000
# 3                       0.000000                          0.000000
# 4                       0.120096                          0.120096
#
#    burn_in_period
# 0            True
# 1            True
# 2            True
# 3            True
# 4            True

# %%
df.columns.tolist()
# Out:
# ['day',
#  'n_cases_caseDB',
#  'n_cases_future_arrival',
#  'n_cases_arrived',
#  'n_cases_waiting_in_queue',
#  'n_cases_in_process',
#  'n_cases_assigned_total',
#  'n_cases_closed_total',
#  'n_agents',
#  'n_busy_agents',
#  'avg_current_queue_waitingtime',
#  'min_current_queue_waitingtime',
#  'max_current_queue_waitingtime',
#  'median_current_queue_waitingtime',
#  'burn_in_period']

# %% [markdown]
# # Cases

# %%
sns.lineplot(data = df[['n_cases_caseDB',
                         'n_cases_future_arrival',
                         'n_cases_arrived',
                         'n_cases_waiting_in_queue',
                         'n_cases_in_process', ################### fix this one
                         'n_cases_assigned_total',
                         'n_cases_closed_total',]])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Agents

# %%
sns.lineplot(data = df[['n_agents',
                         'n_busy_agents',]])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Queue waiting time

# %%
"""
Go over the calculations again - check why mean and median are so similar
"""

sns.lineplot(data = df[['avg_current_queue_waitingtime',
                         'min_current_queue_waitingtime',
                         'max_current_queue_waitingtime',
                         'median_current_queue_waitingtime',]])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Throughput time

# %% [markdown]
# # All runs

# %%
runs = []
for i in list(range(0,int(np.max(experiments.RUN)))):
    
    # load a single run
    df = pd.read_csv("../results/"+str(i)+"/"+str(i)+"_timeseries.csv")
    
    # mark it with specs
    specs = experiments.loc[i].to_dict()
    
    df["F_priority_scheme"] = specs["F_priority_scheme"]
    df["F_number_of_agents"] = specs["F_number_of_agents"]
    df["repetition"] = specs["repetition"]
    df["RUN"] = specs["RUN"]
    
    # add it to a list
    runs.append(df)
    
all_runs = pd.concat(runs)

# %%
all_runs
# Out:
#      day  n_cases_caseDB  n_cases_future_arrival  n_cases_arrived  \
# 0      0            1482                    1481                1
# 1      1            1482                    1478                4
# 2      2            1482                    1476                6
# 3      3            1482                    1473                9
# 4      4            1482                    1472               10
# ..   ...             ...                     ...              ...
# 725  725            1543                      11             1532
# 726  726            1543                      10             1533
# 727  727            1543                      10             1533
# 728  728            1543                       5             1538
# 729  729            1543                       1             1542
#
#      n_cases_waiting_in_queue  n_cases_in_process  n_cases_assigned_total  \
# 0                           0                   0                       0
# 1                           0                   0                       1
# 2                           1                   0                       3
# 3                           2                   0                       4
# 4                           3                   0                       6
# ..                        ...                 ...                     ...
# 725                        77                   0                    1454
# 726                        77                   0                    1455
# 727                        77                   0                    1456
# 728                        77                   0                    1456
# 729                        76                   0                    1462
#
#      n_cases_closed_total  n_agents  n_busy_agents  \
# 0                       0         3              0
# 1                       0         3              1
# 2                       0         3              3
# 3                       1         3              3
# 4                       3         3              3
# ..                    ...       ...            ...
# 725                  1442        12             12
# 726                  1443        12             12
# 727                  1444        12             12
# 728                  1444        12             12
# 729                  1450        12             12
#
#      avg_current_queue_waitingtime  min_current_queue_waitingtime  \
# 0                         0.000000                       0.000000
# 1                         0.000000                       0.000000
# 2                         0.293572                       0.293572
# 3                         0.454841                       0.018522
# 4                         0.682822                       0.586317
# ..                             ...                            ...
# 725                      33.982260                       0.301212
# 726                      34.969881                       0.348081
# 727                      35.947199                       0.580904
# 728                      36.947199                       1.580904
# 729                      38.066825                       0.249363
#
#      max_current_queue_waitingtime  median_current_queue_waitingtime  \
# 0                         0.000000                          0.000000
# 1                         0.000000                          0.000000
# 2                         0.293572                          0.293572
# 3                         0.891161                          0.454841
# 4                         0.754820                          0.707328
# ..                             ...                               ...
# 725                      93.992168                         22.985828
# 726                      94.992168                         23.985828
# 727                      95.992168                         24.985828
# 728                      96.992168                         25.985828
# 729                      97.992168                         27.441605
#
#      burn_in_period F_priority_scheme  F_number_of_agents  repetition   RUN
# 0              True              FCFS                   3           0     0
# 1              True              FCFS                   3           0     0
# 2              True              FCFS                   3           0     0
# 3              True              FCFS                   3           0     0
# 4              True              FCFS                   3           0     0
# ..              ...               ...                 ...         ...   ...
# 725           False               NPS                  12          99  1998
# 726           False               NPS                  12          99  1998
# 727           False               NPS                  12          99  1998
# 728           False               NPS                  12          99  1998
# 729           False               NPS                  12          99  1998
#
# [1459270 rows x 19 columns]

# %%
sns.lineplot(data = df[['avg_current_queue_waitingtime',
                         'min_current_queue_waitingtime',
                         'max_current_queue_waitingtime',
                         'median_current_queue_waitingtime',]])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Notes
#
# - The event-log seems as a reliable source for checking the final performance
# - The source for calculating the queue statistics should be reviewed:
#     - Is caseDB reliable to use at day d for finding n waiting in the queue?
#
# ## Mysterious missing cases
# - Dates in the event-log seems to make sense, but the arrival_q in CaseDB, and case_arrival in evlog only go to day 355 even though the dates of cases seem to make sense.
#
# What is this phenomena?
# - How could the processing time increase?
#     - it doesnt
# - How could initial_delay increase? (initial_delay = waiting time in queue before case gets picked up)
#     - it seems to amount to a year at some point

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Initial theory
#
# - The queue gets so filled up, that the current waiting time is close to a year, and no new cases are therefore picked up.
#     - This would also imply that we cannot calculate any statistics on new cases, as they are waiting in line.
#
# # If true, then:
#
# - Need a way to measure this in an easy-to-understand manner.
#     - CaseDB is reliable, but not that intuitive
#         - It can be used to figure out what is the size of and waiting time in the queue
#     - The event-log has much of the needed information

# %% [markdown]
# # Plots of waiting time over two years: FCFS

# %%
burn_in = 90

runs = all_runs.loc[all_runs.F_priority_scheme == "FCFS"]

"""
Remove burn_in period
"""
runs = runs.loc[runs.day < 365 + burn_in]
runs = runs.loc[runs.day > burn_in]

runs["F_priority_scheme"] = runs.F_priority_scheme.astype("category")
runs.index = list(range(0,len(runs)))

runs
# Out:
#         day  n_cases_caseDB  n_cases_future_arrival  n_cases_arrived  \
# 0        91            1482                    1387               95
# 1        92            1482                    1385               97
# 2        93            1482                    1383               99
# 3        94            1482                    1382              100
# 4        95            1482                    1380              102
# ...     ...             ...                     ...              ...
# 145595  450            1568                     806              762
# 145596  451            1568                     805              763
# 145597  452            1568                     804              764
# 145598  453            1568                     802              766
# 145599  454            1568                     802              766
#
#         n_cases_waiting_in_queue  n_cases_in_process  n_cases_assigned_total  \
# 0                             18                   0                      75
# 1                             19                   0                      76
# 2                             20                   0                      77
# 3                             22                   0                      77
# 4                             21                   0                      79
# ...                          ...                 ...                     ...
# 145595                         0                   0                     760
# 145596                         0                   0                     762
# 145597                         0                   0                     763
# 145598                         0                   0                     764
# 145599                         0                   0                     766
#
#         n_cases_closed_total  n_agents  n_busy_agents  \
# 0                         72         3              3
# 1                         73         3              3
# 2                         74         3              3
# 3                         74         3              3
# 4                         76         3              3
# ...                      ...       ...            ...
# 145595                   753        12              7
# 145596                   756        12              6
# 145597                   759        12              4
# 145598                   762        12              2
# 145599                   763        12              3
#
#         avg_current_queue_waitingtime  min_current_queue_waitingtime  \
# 0                           12.619835                       0.309964
# 1                           11.883277                       0.221394
# 2                           11.244957                       0.299374
# 3                           11.185986                       0.196830
# 4                           10.687683                       0.607996
# ...                               ...                            ...
# 145595                       0.000000                       0.000000
# 145596                       0.000000                       0.000000
# 145597                       0.000000                       0.000000
# 145598                       0.000000                       0.000000
# 145599                       0.000000                       0.000000
#
#         max_current_queue_waitingtime  median_current_queue_waitingtime  \
# 0                           18.966651                         13.621635
# 1                           19.824513                         12.192133
# 2                           20.222737                         12.320593
# 3                           21.222737                         12.738427
# 4                           21.754599                         13.195318
# ...                               ...                               ...
# 145595                       0.000000                          0.000000
# 145596                       0.000000                          0.000000
# 145597                       0.000000                          0.000000
# 145598                       0.000000                          0.000000
# 145599                       0.000000                          0.000000
#
#         burn_in_period F_priority_scheme  F_number_of_agents  repetition   RUN
# 0                 True              FCFS                   3           0     0
# 1                 True              FCFS                   3           0     0
# 2                 True              FCFS                   3           0     0
# 3                 True              FCFS                   3           0     0
# 4                 True              FCFS                   3           0     0
# ...                ...               ...                 ...         ...   ...
# 145595           False              FCFS                  12          99  1995
# 145596           False              FCFS                  12          99  1995
# 145597           False              FCFS                  12          99  1995
# 145598           False              FCFS                  12          99  1995
# 145599           False              FCFS                  12          99  1995
#
# [145600 rows x 19 columns]

# %%
fig = plt.figure(figsize=(14, 8))

sns.lineplot(x = 'day', 
             y = 'avg_current_queue_waitingtime', 
             hue = "F_number_of_agents",
             ci=95,
             data=runs)

plt.xlabel("Average waiting time in queue (days)")
plt.ylabel("Time in days")

plt.title("Baseline waitingtime (FCFS) vs. number of agents")

plt.ylim(0, 150)

plt.savefig("Waiting_time_FCFS.png", dpi=200, bbox_inches = "tight")

plt.show()

# %% [raw]
# ax = sns.lineplot(x = 'day',
#              y = 'avg_current_queue_waitingtime',
#              hue = "F_number_of_agents",
#              ci=95,
#              data=runs)
#
# ax.set(ylim=(0, 150))
# #ax.set(xlim=(0, 275))
#
# plt.savefig("Waiting_time_FCFS.png", dpi=200, bbox_inches = "tight")
# plt.show()

# %% [markdown]
# # Plots of waiting time over two years: All schemes

# %%
#runs = all_runs.loc[all_runs.repetition == 0]

runs = all_runs.loc[all_runs.F_number_of_agents == 3]

#runs = runs.loc[runs.day < 365]
runs["F_priority_scheme"] = runs.F_priority_scheme.astype("category")
runs.index = list(range(0,len(runs)))

runs
# Out:
# C:\Users\Mike\AppData\Local\Temp\ipykernel_22128\1361946698.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   runs["F_priority_scheme"] = runs.F_priority_scheme.astype("category")
#         day  n_cases_caseDB  n_cases_future_arrival  n_cases_arrived  \
# 0         0            1482                    1481                1
# 1         1            1482                    1478                4
# 2         2            1482                    1476                6
# 3         3            1482                    1473                9
# 4         4            1482                    1472               10
# ...     ...             ...                     ...              ...
# 364995  725            1475                      19             1456
# 364996  726            1475                      18             1457
# 364997  727            1475                      17             1458
# 364998  728            1475                      12             1463
# 364999  729            1475                       3             1472
#
#         n_cases_waiting_in_queue  n_cases_in_process  n_cases_assigned_total  \
# 0                              0                   0                       0
# 1                              0                   0                       1
# 2                              1                   0                       3
# 3                              2                   0                       4
# 4                              3                   0                       6
# ...                          ...                 ...                     ...
# 364995                       860                   0                     594
# 364996                       860                   0                     596
# 364997                       861                   0                     596
# 364998                       862                   0                     596
# 364999                       866                   0                     597
#
#         n_cases_closed_total  n_agents  n_busy_agents  \
# 0                          0         3              0
# 1                          0         3              1
# 2                          0         3              3
# 3                          1         3              3
# 4                          3         3              3
# ...                      ...       ...            ...
# 364995                   591         3              3
# 364996                   593         3              3
# 364997                   593         3              3
# 364998                   593         3              3
# 364999                   594         3              3
#
#         avg_current_queue_waitingtime  min_current_queue_waitingtime  \
# 0                            0.000000                       0.000000
# 1                            0.000000                       0.000000
# 2                            0.293572                       0.293572
# 3                            0.454841                       0.018522
# 4                            0.682822                       0.586317
# ...                               ...                            ...
# 364995                     156.719098                       0.177296
# 364996                     156.863567                       0.098466
# 364997                     157.681150                       0.802236
# 364998                     158.498102                       0.893706
# 364999                     158.333983                       0.025916
#
#         max_current_queue_waitingtime  median_current_queue_waitingtime  \
# 0                            0.000000                          0.000000
# 1                            0.000000                          0.000000
# 2                            0.293572                          0.293572
# 3                            0.891161                          0.454841
# 4                            0.754820                          0.707328
# ...                               ...                               ...
# 364995                     367.292168                        136.253833
# 364996                     368.153396                        137.088551
# 364997                     369.153396                        138.062558
# 364998                     370.153396                        139.057461
# 364999                     371.074897                        139.913368
#
#         burn_in_period F_priority_scheme  F_number_of_agents  repetition   RUN
# 0                 True              FCFS                   3           0     0
# 1                 True              FCFS                   3           0     0
# 2                 True              FCFS                   3           0     0
# 3                 True              FCFS                   3           0     0
# 4                 True              FCFS                   3           0     0
# ...                ...               ...                 ...         ...   ...
# 364995           False           NPS-SLA                   3          99  1984
# 364996           False           NPS-SLA                   3          99  1984
# 364997           False           NPS-SLA                   3          99  1984
# 364998           False           NPS-SLA                   3          99  1984
# 364999           False           NPS-SLA                   3          99  1984
#
# [365000 rows x 19 columns]

# %%
ax = sns.lineplot(x = 'day', 
             y = 'avg_current_queue_waitingtime', 
             hue = "F_priority_scheme",
             ci=95,
             data=runs)

ax.set(ylim=(0, 275))
# Out:
# [(0.0, 275.0)]

# %%
#runs = all_runs.loc[all_runs.repetition == 0]

runs = all_runs.loc[all_runs.F_number_of_agents == 6]

#runs = runs.loc[runs.day < 365]
runs["F_priority_scheme"] = runs.F_priority_scheme.astype("category")
runs.index = list(range(0,len(runs)))

runs
# Out:
# C:\Users\Mike\AppData\Local\Temp\ipykernel_22128\3084550090.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   runs["F_priority_scheme"] = runs.F_priority_scheme.astype("category")
#         day  n_cases_caseDB  n_cases_future_arrival  n_cases_arrived  \
# 0         0            1519                    1516                3
# 1         1            1519                    1514                5
# 2         2            1519                    1512                7
# 3         3            1519                    1510                9
# 4         4            1519                    1510                9
# ...     ...             ...                     ...              ...
# 364995  725            1664                      26             1638
# 364996  726            1664                      26             1638
# 364997  727            1664                      22             1642
# 364998  728            1664                      12             1652
# 364999  729            1664                       5             1659
#
#         n_cases_waiting_in_queue  n_cases_in_process  n_cases_assigned_total  \
# 0                              0                   0                       0
# 1                              0                   0                       3
# 2                              0                   0                       5
# 3                              0                   0                       7
# 4                              0                   0                       9
# ...                          ...                 ...                     ...
# 364995                       510                   0                    1127
# 364996                       507                   0                    1131
# 364997                       507                   0                    1131
# 364998                       511                   0                    1131
# 364999                       521                   0                    1131
#
#         n_cases_closed_total  n_agents  n_busy_agents  \
# 0                          0         6              0
# 1                          0         6              3
# 2                          0         6              5
# 3                          3         6              4
# 4                          4         6              5
# ...                      ...       ...            ...
# 364995                  1121         6              6
# 364996                  1125         6              6
# 364997                  1125         6              6
# 364998                  1125         6              6
# 364999                  1125         6              6
#
#         avg_current_queue_waitingtime  min_current_queue_waitingtime  \
# 0                            0.000000                       0.000000
# 1                            0.000000                       0.000000
# 2                            0.000000                       0.000000
# 3                            0.000000                       0.000000
# 4                            0.000000                       0.000000
# ...                               ...                            ...
# 364995                      66.901162                       0.095077
# 364996                      67.190665                       0.774153
# 364997                      68.190665                       1.774153
# 364998                      68.653546                       0.337115
# 364999                      68.327087                       0.039923
#
#         max_current_queue_waitingtime  median_current_queue_waitingtime  \
# 0                            0.000000                          0.000000
# 1                            0.000000                          0.000000
# 2                            0.000000                          0.000000
# 3                            0.000000                          0.000000
# 4                            0.000000                          0.000000
# ...                               ...                               ...
# 364995                     140.630474                         61.852222
# 364996                     140.260038                         61.787665
# 364997                     141.260038                         62.787665
# 364998                     142.260038                         62.525969
# 364999                     143.260038                         62.118047
#
#         burn_in_period F_priority_scheme  F_number_of_agents  repetition   RUN
# 0                 True              FCFS                   6           0     5
# 1                 True              FCFS                   6           0     5
# 2                 True              FCFS                   6           0     5
# 3                 True              FCFS                   6           0     5
# 4                 True              FCFS                   6           0     5
# ...                ...               ...                 ...         ...   ...
# 364995           False           NPS-SLA                   6          99  1989
# 364996           False           NPS-SLA                   6          99  1989
# 364997           False           NPS-SLA                   6          99  1989
# 364998           False           NPS-SLA                   6          99  1989
# 364999           False           NPS-SLA                   6          99  1989
#
# [365000 rows x 19 columns]

# %%
ax = sns.lineplot(x = 'day', 
             y = 'avg_current_queue_waitingtime', 
             hue = "F_priority_scheme",
             ci=95,
             data=runs)

ax.set(ylim=(0, 275))
# Out:
# [(0.0, 275.0)]

# %%
#runs = all_runs.loc[all_runs.repetition == 0]

runs = all_runs.loc[all_runs.F_number_of_agents == 9]

#runs = runs.loc[runs.day < 365]
runs["F_priority_scheme"] = runs.F_priority_scheme.astype("category")
runs.index = list(range(0,len(runs)))

runs
# Out:
# C:\Users\Mike\AppData\Local\Temp\ipykernel_22128\3821699410.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   runs["F_priority_scheme"] = runs.F_priority_scheme.astype("category")
#         day  n_cases_caseDB  n_cases_future_arrival  n_cases_arrived  \
# 0         0            1507                    1504                3
# 1         1            1507                    1503                4
# 2         2            1507                    1502                5
# 3         3            1507                    1500                7
# 4         4            1507                    1499                8
# ...     ...             ...                     ...              ...
# 364995  725            1558                      13             1545
# 364996  726            1558                       8             1550
# 364997  727            1558                       7             1551
# 364998  728            1558                       7             1551
# 364999  729            1558                       4             1554
#
#         n_cases_waiting_in_queue  n_cases_in_process  n_cases_assigned_total  \
# 0                              0                   0                       0
# 1                              0                   0                       3
# 2                              0                   0                       4
# 3                              0                   0                       5
# 4                              0                   0                       7
# ...                          ...                 ...                     ...
# 364995                       178                   0                    1365
# 364996                       177                   0                    1368
# 364997                       180                   0                    1370
# 364998                       181                   0                    1370
# 364999                       179                   0                    1372
#
#         n_cases_closed_total  n_agents  n_busy_agents  \
# 0                          0         9              0
# 1                          0         9              3
# 2                          0         9              4
# 3                          3         9              2
# 4                          3         9              4
# ...                      ...       ...            ...
# 364995                  1356         9              9
# 364996                  1359         9              9
# 364997                  1361         9              9
# 364998                  1361         9              9
# 364999                  1363         9              9
#
#         avg_current_queue_waitingtime  min_current_queue_waitingtime  \
# 0                            0.000000                       0.000000
# 1                            0.000000                       0.000000
# 2                            0.000000                       0.000000
# 3                            0.000000                       0.000000
# 4                            0.000000                       0.000000
# ...                               ...                            ...
# 364995                      19.500408                       0.353250
# 364996                      19.882786                       0.551160
# 364997                      20.065302                       0.379841
# 364998                      20.952537                       0.654820
# 364999                      21.700181                       1.654820
#
#         max_current_queue_waitingtime  median_current_queue_waitingtime  \
# 0                            0.000000                          0.000000
# 1                            0.000000                          0.000000
# 2                            0.000000                          0.000000
# 3                            0.000000                          0.000000
# 4                            0.000000                          0.000000
# ...                               ...                               ...
# 364995                      43.001908                         20.041151
# 364996                      43.253314                         20.667526
# 364997                      42.682689                         20.562094
# 364998                      43.682689                         21.391319
# 364999                      44.367413                         22.374879
#
#         burn_in_period F_priority_scheme  F_number_of_agents  repetition   RUN
# 0                 True              FCFS                   9           0    10
# 1                 True              FCFS                   9           0    10
# 2                 True              FCFS                   9           0    10
# 3                 True              FCFS                   9           0    10
# 4                 True              FCFS                   9           0    10
# ...                ...               ...                 ...         ...   ...
# 364995           False           NPS-SLA                   9          99  1994
# 364996           False           NPS-SLA                   9          99  1994
# 364997           False           NPS-SLA                   9          99  1994
# 364998           False           NPS-SLA                   9          99  1994
# 364999           False           NPS-SLA                   9          99  1994
#
# [365000 rows x 19 columns]

# %%
ax = sns.lineplot(x = 'day', 
             y = 'avg_current_queue_waitingtime', 
             hue = "F_priority_scheme",
             ci=95,
             data=runs)

ax.set(ylim=(0, 275))
# Out:
# [(0.0, 275.0)]

# %%
#runs = all_runs.loc[all_runs.repetition == 0]

runs = all_runs.loc[all_runs.F_number_of_agents == 12]

#runs = runs.loc[runs.day < 365]
runs["F_priority_scheme"] = runs.F_priority_scheme.astype("category")
runs.index = list(range(0,len(runs)))

runs
# Out:
# C:\Users\Mike\AppData\Local\Temp\ipykernel_22128\393354896.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   runs["F_priority_scheme"] = runs.F_priority_scheme.astype("category")
#         day  n_cases_caseDB  n_cases_future_arrival  n_cases_arrived  \
# 0         0            1621                    1618                3
# 1         1            1621                    1614                7
# 2         2            1621                    1612                9
# 3         3            1621                    1610               11
# 4         4            1621                    1610               11
# ...     ...             ...                     ...              ...
# 364265  725            1543                      11             1532
# 364266  726            1543                      10             1533
# 364267  727            1543                      10             1533
# 364268  728            1543                       5             1538
# 364269  729            1543                       1             1542
#
#         n_cases_waiting_in_queue  n_cases_in_process  n_cases_assigned_total  \
# 0                              0                   0                       0
# 1                              0                   0                       3
# 2                              1                   0                       7
# 3                              0                   0                       9
# 4                              0                   0                      11
# ...                          ...                 ...                     ...
# 364265                        77                   0                    1454
# 364266                        77                   0                    1455
# 364267                        77                   0                    1456
# 364268                        77                   0                    1456
# 364269                        76                   0                    1462
#
#         n_cases_closed_total  n_agents  n_busy_agents  \
# 0                          0        12              0
# 1                          0        12              3
# 2                          0        12              7
# 3                          3        12              6
# 4                          5        12              6
# ...                      ...       ...            ...
# 364265                  1442        12             12
# 364266                  1443        12             12
# 364267                  1444        12             12
# 364268                  1444        12             12
# 364269                  1450        12             12
#
#         avg_current_queue_waitingtime  min_current_queue_waitingtime  \
# 0                            0.000000                       0.000000
# 1                            0.000000                       0.000000
# 2                            0.009496                       0.009496
# 3                            0.000000                       0.000000
# 4                            0.000000                       0.000000
# ...                               ...                            ...
# 364265                      33.982260                       0.301212
# 364266                      34.969881                       0.348081
# 364267                      35.947199                       0.580904
# 364268                      36.947199                       1.580904
# 364269                      38.066825                       0.249363
#
#         max_current_queue_waitingtime  median_current_queue_waitingtime  \
# 0                            0.000000                          0.000000
# 1                            0.000000                          0.000000
# 2                            0.009496                          0.009496
# 3                            0.000000                          0.000000
# 4                            0.000000                          0.000000
# ...                               ...                               ...
# 364265                      93.992168                         22.985828
# 364266                      94.992168                         23.985828
# 364267                      95.992168                         24.985828
# 364268                      96.992168                         25.985828
# 364269                      97.992168                         27.441605
#
#         burn_in_period F_priority_scheme  F_number_of_agents  repetition   RUN
# 0                 True              FCFS                  12           0    15
# 1                 True              FCFS                  12           0    15
# 2                 True              FCFS                  12           0    15
# 3                 True              FCFS                  12           0    15
# 4                 True              FCFS                  12           0    15
# ...                ...               ...                 ...         ...   ...
# 364265           False               NPS                  12          99  1998
# 364266           False               NPS                  12          99  1998
# 364267           False               NPS                  12          99  1998
# 364268           False               NPS                  12          99  1998
# 364269           False               NPS                  12          99  1998
#
# [364270 rows x 19 columns]

# %%
ax = sns.lineplot(x = 'day', 
             y = 'avg_current_queue_waitingtime', 
             hue = "F_priority_scheme",
             ci=95,
             data=runs)

ax.set(ylim=(0, 275))
# Out:
# [(0.0, 275.0)]
